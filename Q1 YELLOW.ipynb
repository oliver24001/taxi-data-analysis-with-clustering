# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('yellow2019_0.csv', parse_dates= ['tpep_pickup_datetime','tpep_dropoff_datetime'])
data
# Out:
#          Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                 0       1.0  2019-02-01 00:59:04   2019-02-01 01:07:27
# 1                 1       1.0  2019-02-01 00:33:09   2019-02-01 01:03:58
# 2                 2       1.0  2019-02-01 00:09:03   2019-02-01 00:09:16
# 3                 3       1.0  2019-02-01 00:45:38   2019-02-01 00:51:10
# 4                 4       1.0  2019-02-01 00:25:30   2019-02-01 00:28:14
# ...             ...       ...                  ...                   ...
# 3618800     3683096       2.0  2019-02-14 23:35:12   2019-02-14 23:43:02
# 3618801     3862807       2.0  2019-02-14 23:40:40   2019-02-14 23:54:18
# 3618802     5978834       2.0  2019-02-14 17:42:43   2019-02-14 17:55:02
# 3618803     5978835       2.0  2019-02-14 17:56:51   2019-02-14 17:57:29
# 3618804     5978836       2.0  2019-02-14 17:57:53   2019-02-15 08:51:09
#
#          passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# ...

# %%
data['travel_time'] = data['dropoff_datetime']-data['pickup_datetime']
data
# Out:
#           Unnamed: 0  Unnamed: 0.1 hvfhs_license_num dispatching_base_num  \
# 0                537           537            HV0003               B02872
# 1                897           897            HV0002               B02914
# 2               3497          3497            HV0005               B02510
# 3               7422          7422            HV0003               B02764
# 4              10109         10109            HV0003               B02864
# 5              10297         10297            HV0002               B02914
# 6              12913         12913            HV0003               B02884
# 7              14226         14226            HV0003               B02872
# 8              14854         14854            HV0002               B02914
# 9              17698         17698            HV0002               B02914
# 10             18165         18165            HV0003               B02835
# 11             22829         22829            HV0003               B02865
# ...

# %%
data.to_csv

# %%
data.groupby(data['tpep_pickup_datetime'].dt.hour).count()
# Out:
#                       Unnamed: 0  VendorID  tpep_pickup_datetime  \
# tpep_pickup_datetime
# 0                         100149    100149                100149
# 1                          70027     70027                 70027
# 2                          49976     49976                 49976
# 3                          35304     35304                 35304
# 4                          27214     27214                 27214
# 5                          33338     33338                 33338
# 6                          79632     79632                 79632
# 7                         141016    141016                141016
# 8                         174057    174057                174057
# 9                         174901    174901                174901
# 10                        170649    170649                170649
# 11                        174470    174470                174470
# 12                        185290    185290                185290
# ...

# %%
pickupdf=data.sort_values(by=['tpep_pickup_datetime'])
pickupdf
# Out:
#          Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 5327           5514       4.0  2019-02-01 00:00:00   2019-02-01 00:06:27
# 215816       216122       2.0  2019-02-01 00:00:00   2019-02-01 18:06:48
# 693             718       1.0  2019-02-01 00:00:00   2019-02-01 00:18:57
# 6726           6970       1.0  2019-02-01 00:00:00   2019-02-01 00:18:52
# 2141           2207       1.0  2019-02-01 00:00:02   2019-02-01 00:16:33
# ...             ...       ...                  ...                   ...
# 3613571     3614021       1.0  2019-02-14 23:59:55   2019-02-15 00:10:25
# 3618668     3623458       2.0  2019-02-14 23:59:57   2019-02-15 00:09:43
# 3618650     3622778       2.0  2019-02-14 23:59:57   2019-02-15 00:05:00
# 3618689     3624180       2.0  2019-02-14 23:59:57   2019-02-15 00:08:03
# 3614801     3615255       1.0  2019-02-14 23:59:58   2019-02-15 00:06:10
#
#          passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# ...

# %%
pickup_byhour=data.groupby([data['tpep_pickup_datetime'].dt.hour,data['PULocationID']]).size()
pickup_byhour
pickup_byhour=pd.DataFrame(pickup_byhour)
pickup_byhour.to_csv('YELLOW_pickup_byhour.csv')

# %%
pickup_byday=data.groupby([data['tpep_pickup_datetime'].dt.day,data['PULocationID']]).size()
pickup_byday
pickup_byday=pd.DataFrame(pickup_byday)
pickup_byday.to_csv('YELLOW_pickup_byday.csv')

# %%
pickuppeak_time=data.groupby([data['tpep_pickup_datetime'].dt.hour]).size()
pickuppeak_time
# Out:
# tpep_pickup_datetime
# 0     100149
# 1      70027
# 2      49976
# 3      35304
# 4      27214
# 5      33338
# 6      79632
# 7     141016
# 8     174057
# 9     174901
# 10    170649
# 11    174470
# 12    185290
# 13    187132
# 14    198519
# 15    203571
# 16    193258
# 17    218037
# 18    245079
# 19    226452
# 20    201501
# 21    196176
# 22    189333
# 23    143724
# dtype: int64

# %%
dropoffdf=data.sort_values(by=['tpep_dropoff_datetime'])
dropoffdf
# Out:
#          Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 3213617     3214008       1.0  2019-02-13 15:15:00   2018-02-13 17:34:31
# 5822           6033       2.0  2019-02-01 00:00:43   2019-02-01 00:00:50
# 202             208       2.0  2019-02-01 00:01:38   2019-02-01 00:01:41
# 4682           4846       1.0  2019-02-01 00:01:00   2019-02-01 00:01:51
# 1638           1688       2.0  2019-02-01 00:02:01   2019-02-01 00:02:04
# ...             ...       ...                  ...                   ...
# 3608617     3609053       2.0  2019-02-14 23:39:50   2019-02-15 23:32:27
# 3612221     3612665       2.0  2019-02-14 23:58:56   2019-02-15 23:32:59
# 3612177     3612621       2.0  2019-02-14 23:52:47   2019-02-15 23:37:23
# 3609832     3610272       2.0  2019-02-14 23:40:35   2019-02-15 23:38:08
# 1581419     1581741       1.0  2019-02-07 07:28:18   2019-02-25 08:36:17
#
#          passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# ...

# %%
dropoff_byhour=data.groupby([data['tpep_dropoff_datetime'].dt.hour,data['DOLocationID']]).size()
dropoff_byhour
dropoff_byhour=pd.DataFrame(dropoff_byhour)
dropoff_byhour.to_csv('YELLOW_dropoff_byhour.csv')

# %%
dropoff_byday=data.groupby([data['tpep_dropoff_datetime'].dt.day,data['DOLocationID']]).size()
dropoff_byday
dropoff_byday=pd.DataFrame(dropoff_byday)
dropoff_byday.to_csv('YELLOW_dropoff_byday.csv')

# %%
dropoffpeak_time=data.groupby([data['tpep_dropoff_datetime'].dt.hour]).size()
dropoffpeak_time
# Out:
# tpep_dropoff_datetime
# 0     110402
# 1      76209
# 2      53683
# 3      36931
# 4      28748
# 5      29941
# 6      69260
# 7     124611
# 8     165976
# 9     176343
# 10    172743
# 11    172003
# 12    185378
# 13    184529
# 14    193014
# 15    203658
# 16    194196
# 17    209188
# 18    245255
# 19    236749
# 20    204880
# 21    197431
# 22    192920
# 23    154757
# dtype: int64
