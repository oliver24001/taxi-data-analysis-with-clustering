# %%
import numpy as np
import pandas as pd

from pyproj import Proj, transform

# %%
inProj = Proj(init='epsg:3857')
outProj = Proj(init='epsg:4326')
x1,y1 = (-8235084.52207201,4971738.91614184)
x2,y2 = transform(inProj,outProj,x1,y1)
print (x2 ,y2)
# Out:
# -73.97702292193391 40.72415214273837
# C:\Users\Alex\anaconda3\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\Alex\anaconda3\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# ...

# %%
data=pd.read_excel('taxi_zones_coordinate ESG3857.xlsx')
data
# Out:
#                X            Y  OBJECTID  Shape_Leng  Shape_Area  \
# 0   -8257322.018  4966652.597         1    0.116357    0.000782
# 1   -8218286.728  4957291.835         2    0.433470    0.004866
# 2   -8220886.389  4992580.187         3    0.084341    0.000314
# 3   -8235084.522  4971738.916         4    0.043567    0.000112
# 4   -8258785.193  4946241.476         5    0.092146    0.000498
# ..           ...          ...       ...         ...         ...
# 258 -8221651.398  4997470.717       259    0.126750    0.000395
# 259 -8226923.730  4975065.828       260    0.133514    0.000422
# 260 -8239080.497  4969509.940       261    0.027120    0.000034
# 261 -8231612.122  4979436.180       262    0.049064    0.000122
# 262 -8232210.817  4979724.550       263    0.037017    0.000066
#
#                         zone  LocationID        borough
# 0             Newark Airport           1            EWR
# 1                Jamaica Bay           2         Queens
# ...

# %%
inProj = Proj(init='epsg:3857')
outProj = Proj(init='epsg:4326')
X=[]
Y=[]
for i in range (0,263):
    x1 , y1 = data.X[i] , data.Y[i]
    x2,y2 =transform(inProj,outProj,data.X[i],data.Y[i])
    X.append(x2)
    Y.append(y2)

X=pd.DataFrame(X)
Y=pd.DataFrame(Y)
data=pd.concat ([data,Y,X],axis=1)
# Out:
# C:\Users\Alex\anaconda3\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\Alex\anaconda3\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# ...

# %%
data
# Out:
#                X            Y  OBJECTID  Shape_Leng  Shape_Area  \
# 0   -8257322.018  4966652.597         1    0.116357    0.000782
# 1   -8218286.728  4957291.835         2    0.433470    0.004866
# 2   -8220886.389  4992580.187         3    0.084341    0.000314
# 3   -8235084.522  4971738.916         4    0.043567    0.000112
# 4   -8258785.193  4946241.476         5    0.092146    0.000498
# ..           ...          ...       ...         ...         ...
# 258 -8221651.398  4997470.717       259    0.126750    0.000395
# 259 -8226923.730  4975065.828       260    0.133514    0.000422
# 260 -8239080.497  4969509.940       261    0.027120    0.000034
# 261 -8231612.122  4979436.180       262    0.049064    0.000122
# 262 -8232210.817  4979724.550       263    0.037017    0.000066
#
#                         zone  LocationID        borough          0          0
# 0             Newark Airport           1            EWR  40.689516 -74.176786
# ...

# %%
data[(data.LocationID==55)]
# Out:
#               X            Y  OBJECTID  Shape_Leng  Shape_Area          zone  \
# 54 -8236581.905  4950133.342        55    0.149957    0.000736  Coney Island
#
#     LocationID   borough        0          0
# 54          55  Brooklyn  40.5769 -73.990474
